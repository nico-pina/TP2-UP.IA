# %%
import pandas as pd

# %%
df = pd.read_csv("../data/1. raw/smoking_prediction.xlsx - smoking_prediction.csv")

# %%
df.shape
# Out:
# (50000, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   gender               50000 non-null  object
#  2   age                  50000 non-null  int64
#  3   height(cm)           50000 non-null  int64
#  4   weight(kg)           50000 non-null  int64
#  5   waist(cm)            50000 non-null  float64
#  6   eyesight(left)       50000 non-null  float64
#  7   eyesight(right)      50000 non-null  float64
#  8   hearing(left)        50000 non-null  float64
#  9   hearing(right)       50000 non-null  float64
#  10  systolic             50000 non-null  float64
#  11  relaxation           50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
#  13  Cholesterol          50000 non-null  float64
#  14  triglyceride         50000 non-null  float64
# ...

# %%
df.head(10)
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       3.38            0.04
# 1   1      F   40         160          60       3.38            0.01
# 2   2      M   55         170          60       3.33            0.01
# 3   3      M   40         165          70       3.67            0.05
# 4   4      F   40         155          60       3.58            0.04
# 5   5      M   30         180          75       3.54            0.04
# 6   6      M   40         160          60       3.55            0.04
# 7   7      M   45         165          90       4.00            0.04
# 8   9      F   50         150          60       3.54            0.00
# 9  10      M   45         175          75       3.71            0.04
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0             0.04           0.04            0.04  ...        0.51
# 1             0.00           0.04            0.04  ...        0.50
# ...

# %%
df.tail(10)
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 49990  27311      F   40         160          50       3.04            0.00
# 49991  27314      M   35         170          65       3.29            0.04
# 49992  27316      M   45         170          65       3.46            0.04
# 49993  27320      M   25         180          80       3.71            0.05
# 49994  27329      F   40         160          65       3.17            0.04
# 49995  27343      M   50         160          55       2.96            0.00
# 49996  27350      M   30         170          70       3.33            0.05
# 49997  27351      M   20         165          65       3.54            0.05
# 49998  27352      F   60         160          45       2.96            0.00
# 49999  27354      M   45         170          80       4.00            0.05
#
#        eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# ...

# %%
df["dental caries"].unique() # se revisó porque el df.info() lo generó como entero y se verificó que tomaran valores dicotómicos.
# Out:
# array([0, 1])

# %%
df.shape
# Out:
# (50000, 27)

# %%
df[["dental caries", "gender", "oral", "tartar"]].nunique() # impeccionamos la cardinalidad de columnas que deben tener 1 o 2 valores distintos. Así revisamos errores de formato en algunas columnas
# Out:
# dental caries    2
# gender           2
# oral             1
# tartar           2
# dtype: int64

# %%
df["oral"].unique() # Verificamos que solo tiene un valor. Por lo que no se considerará en el entrenamiento
# Out:
# array(['Y'], dtype=object)

# %%
df["oral"].value_counts()
# Out:
# oral
# Y    50000
# Name: count, dtype: int64
